# %% [markdown]
# # lesson4 練習問題

# %% [markdown]
# ## 4-0. 準備
#
# pandasで使用するcsvファイルをダウンロードします。<br>
# カリフォルニア州の住宅の区画についてのデータセットで、下記に詳しい説明が記載されています。<br>
# https://developers.google.com/machine-learning/crash-course/california-housing-data-description?hl=ja

# %%
# pandasのwarningを抑制
import warnings
warnings.filterwarnings("ignore")

# %%
# %%bash
# wget -q https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv

# %% [markdown]
# ## 4-1. ファイル読み込みと画面への表示
#
# 4-0.でダウンロードしたTokyo_20200101_20221231.csvファイルをpandasのData Frameに格納し、<br>
# 画面に表示してください。なお、pandasライブラリをimportすることを忘れないように気を付けましょう。

# %%
# ライブラリインポート処理を下記に記述してください。
import pandas as pd

# %%
# csvファイルをpandasのData Frameに格納する処理を記述してください。
df = pd.read_csv("california_housing_train.csv")

# %%
# DataFrameを画面に表示する処理を記述してください。
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %% [markdown]
# ## 4-2.各種統計量の確認
#
# Data Frameを確認し、統計データを確認してみましょう。
#
# 1. 平均値・最大値・最小値・分散・標準偏差
# 2. 各列どうしの相関係数
# 3. 人口(population)が1000を上回っている区画数

# %%
# 平均値・最大値・最小値・分散・標準偏差を確認する処理を記述してください。
print("平均値")
print(df.mean())

print("最大値")
print(df.max())

print("最小値")
print(df.min())

print("分散")
print(df.var())

print("標準偏差")
print(df.std())
# Out:
# 平均値
# longitude               -119.562108
# latitude                  35.625225
# housing_median_age        28.589353
# total_rooms             2643.664412
# total_bedrooms           539.410824
# population              1429.573941
# households               501.221941
# median_income              3.883578
# median_house_value    207300.912353
# dtype: float64
# 最大値
# longitude               -114.3100
# latitude                  41.9500
# housing_median_age        52.0000
# total_rooms            37937.0000
# total_bedrooms          6445.0000
# population             35682.0000
# households              6082.0000
# median_income             15.0001
# median_house_value    500001.0000
# dtype: float64
# 最小値
# longitude              -124.3500
# latitude                 32.5400
# housing_median_age        1.0000
# total_rooms               2.0000
# total_bedrooms            1.0000
# population                3.0000
# households                1.0000
# median_income             0.4999
# median_house_value    14999.0000
# dtype: float64
# 分散
# longitude             4.020692e+00
# latitude              4.568221e+00
# housing_median_age    1.584310e+02
# total_rooms           4.752169e+06
# total_bedrooms        1.776618e+05
# population            1.317566e+06
# households            1.478563e+05
# median_income         3.641061e+00
# median_house_value    1.345223e+10
# dtype: float64
# 標準偏差
# longitude                  2.005166
# latitude                   2.137340
# housing_median_age        12.586937
# total_rooms             2179.947071
# total_bedrooms           421.499452
# population              1147.852959
# households               384.520841
# median_income              1.908157
# median_house_value    115983.764387
# dtype: float64

# %%
# 各列どうしの相関係数を確認する処理を記述してください。
df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925208           -0.114250     0.047010
# latitude            -0.925208  1.000000            0.016454    -0.038773
# housing_median_age  -0.114250  0.016454            1.000000    -0.360984
# total_rooms          0.047010 -0.038773           -0.360984     1.000000
# total_bedrooms       0.071802 -0.069373           -0.320434     0.928403
# population           0.101674 -0.111261           -0.295890     0.860170
# households           0.059628 -0.074902           -0.302754     0.919018
# median_income       -0.015485 -0.080303           -0.115932     0.195383
# median_house_value  -0.044982 -0.144917            0.106758     0.130991
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071802    0.101674    0.059628      -0.015485
# latitude                 -0.069373   -0.111261   -0.074902      -0.080303
# housing_median_age       -0.320434   -0.295890   -0.302754      -0.115932
# total_rooms               0.928403    0.860170    0.919018       0.195383
# total_bedrooms            1.000000    0.881169    0.980920      -0.013495
# population                0.881169    1.000000    0.909247      -0.000638
# households                0.980920    0.909247    1.000000       0.007644
# median_income            -0.013495   -0.000638    0.007644       1.000000
# median_house_value        0.045783   -0.027850    0.061031       0.691871
#
#                     median_house_value
# longitude                    -0.044982
# latitude                     -0.144917
# housing_median_age            0.106758
# total_rooms                   0.130991
# total_bedrooms                0.045783
# population                   -0.027850
# households                    0.061031
# median_income                 0.691871
# median_house_value            1.000000

# %%
# 人口(population)が1000を上回っている区画数を確認するための処理を記述してください。
df_high_population = df[df["population"] > 1000]

df_high_population
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 6        -114.58     33.61                25.0       2907.0           680.0
# 8        -114.59     33.61                34.0       4789.0          1175.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# ...          ...       ...                 ...          ...             ...
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 6          1841.0       633.0         2.6768             82400.0
# 8          3134.0      1056.0         2.1782             58400.0
# 10         2434.0       824.0         2.6797             86500.0
# ...           ...         ...            ...                 ...
# 16991      1343.0       479.0         2.4805             73200.0
# 16993      1152.0       435.0         3.0806            106700.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
#
# [10299 rows x 9 columns]

# %% [markdown]
# ## 4-3.データフレームの操作
#
# Data Frameを以下の条件で絞り込みを行ってください。
#
# 1. 1001行目~2000行目までのデータ
# 2. 経度が-118°以上かつ緯度33°以上のデータ
#
# Data Frameに以下の列を追加してください。
#
# 3. 各区画の人口当たりの部屋数
# 4. 人口について標準化した列
#
# ここでの標準化とは下記の式であらわされる操作のことです。
#
# $$
# Z = \frac{x-\bar{x}}{s}
# $$
#
# $$
# x:観測値, \bar{x}:観測値の平均値, s:観測値の標準偏差, Z:標準化された値
# $$

# %%
# 1001行目~2000行目のデータを絞り込む処理を記述してください。
df_middle = df[1000:2000] # indexに注意

df_middle
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1000    -117.10     33.36                19.0       3518.0           658.0
# 1001    -117.10     33.17                12.0       2465.0           412.0
# 1002    -117.10     33.15                 5.0       3159.0           685.0
# 1003    -117.10     33.14                 7.0      10665.0          2576.0
# 1004    -117.10     33.12                12.0        961.0           342.0
# ...         ...       ...                 ...          ...             ...
# 1995    -117.31     34.02                18.0       1634.0           274.0
# 1996    -117.31     33.97                28.0       3420.0           691.0
# 1997    -117.31     33.75                19.0       3173.0           678.0
# 1998    -117.31     33.67                 9.0        981.0           169.0
# 1999    -117.31     33.25                14.0       3483.0           764.0
#
#       population  households  median_income  median_house_value
# 1000      2091.0       610.0         3.2614            168800.0
# 1001      1226.0       428.0         5.4819            183800.0
# 1002      1398.0       581.0         3.1467            161100.0
# 1003      4917.0      2424.0         2.3171            159500.0
# 1004       315.0       201.0         0.8130            275000.0
# ...          ...         ...            ...                 ...
# 1995       899.0       285.0         5.2139            129300.0
# 1996      1502.0       656.0         3.4896            140300.0
# 1997      2204.0       606.0         2.1484            129200.0
# 1998       596.0       156.0         3.1832            157400.0
# 1999      2140.0       687.0         3.1250            102300.0
#
# [1000 rows x 9 columns]

# %%
# 経度(longitude)が-118°以上かつ緯度(latitude)33°以上のデータで絞り込む処理を記述してください。
df_east_north = df.query("longitude >= -118 and latitude >= 33") # df[(df["longitude"] >= -118) & (df["latitude"] >= 33)] としてもOK

df_east_north
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -114.31     34.19                15.0       5612.0          1283.0
# 1       -114.47     34.40                19.0       7650.0          1901.0
# 2       -114.56     33.69                17.0        720.0           174.0
# 3       -114.57     33.64                14.0       1501.0           337.0
# 4       -114.57     33.57                20.0       1454.0           326.0
# ...         ...       ...                 ...          ...             ...
# 4268    -118.00     33.73                26.0       2236.0           280.0
# 4269    -118.00     33.71                19.0       4808.0          1029.0
# 4270    -118.00     33.68                12.0       5241.0           985.0
# 4271    -118.00     33.66                25.0       4041.0           903.0
# 4272    -118.00     33.66                16.0       2809.0           708.0
#
#       population  households  median_income  median_house_value
# 0         1015.0       472.0         1.4936             66900.0
# 1         1129.0       463.0         1.8200             80100.0
# 2          333.0       117.0         1.6509             85700.0
# 3          515.0       226.0         3.1917             73400.0
# 4          624.0       262.0         1.9250             65500.0
# ...          ...         ...            ...                 ...
# 4268       809.0       282.0         6.7395            342800.0
# 4269      2422.0       971.0         4.0121            279700.0
# 4270      2048.0       943.0         6.4858            285400.0
# 4271      1689.0       784.0         4.2289            442700.0
# 4272      1260.0       638.0         3.2353            252900.0
#
# [3191 rows x 9 columns]

# %%
# 各区画の人口当たりの部屋数用の列を追加する処理を記述してください。
df_analize = df

df_analize["room_per_population"] = df_analize["total_rooms"] / df_analize["population"]

df_analize
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  \
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
#        room_per_population
# 0                 5.529064
# 1                 6.775908
# 2                 2.162162
# 3                 2.914563
# 4                 2.330128
# ...                    ...
# 16995             2.444322
# 16996             1.967337
# 16997             2.151929
# 16998             2.058552
# 16999             2.258065
#
# [17000 rows x 10 columns]

# %%
# 人口について標準化する処理を記述してください。
df_analize = df

df_analize["standardized_population"] = (df_analize["population"] / df_analize["population"].mean()) / df_analize["population"].std()

df_analize
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  \
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
#        room_per_population  standardized_population
# 0                 5.529064                 0.000619
# 1                 6.775908                 0.000688
# 2                 2.162162                 0.000203
# 3                 2.914563                 0.000314
# 4                 2.330128                 0.000380
# ...                    ...                      ...
# 16995             2.444322                 0.000553
# 16996             1.967337                 0.000728
# 16997             2.151929                 0.000758
# 16998             2.058552                 0.000791
# 16999             2.258065                 0.000491
#
# [17000 rows x 11 columns]

# %% [markdown]
# ## 4-4.データフレームの保存
#
# 4-3.で作成したData Frameをcsvファイルで保存してください。

# %%
# csvファイルで保存する処理を記述してください。
df_analized.to_csv("analized.csv")

# %% [markdown]
# ## 4-5.グラフ描画
#
# 人口(population)と収入の中央値(median_incom)についてそれぞれ正規化し、グラフにプロットしてください。

# %%
# 正規化/グラフ描画処理を記述してください。
df_analize = df.copy()

df_analize["normalized_population"] = \
                                        (df_analize["population"] - df_analize["population"].min()) \
                                        / (df_analize["population"].max() - df_analize["population"].min())

df_analize["normalized_median_income"] = \
                                        (df_analize["median_income"] - df_analize["median_income"].min()) \
                                        / (df_analize["median_income"].max() - df_analize["median_income"].min())

df_analize[["normalized_population", "normalized_median_income"]].plot(figsize=(20,10))
# Out:
# <Axes: >
